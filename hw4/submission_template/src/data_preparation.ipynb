# %%
import pandas as pd

# %%
headers = ['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name', 'Complaint Type',
          'Descriptor', 'Location Type', 'Incident Zip', 'Incident Address', 'Street Name', 'Cross Street 1', 
          'Cross Street 2', 'Intersection Street 1', 'Intersection Street 2', 'Address Type', 'City', 'Landmark',
          'Facility Type', 'Status', 'Due Date', 'Resolution Description', 'Resolution Action Updated Date',
          'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)', 'Y Coordinate (State plane)',
          'Open Data Channel Type', 'Park Facility Name', 'Park Borough', 'Vehicle Type', 'Taxi Company Borough',
          'Taxi Pick up Location', 'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
          'Latitude', 'Longitude', 'Location']
df = pd.read_csv('~/nyc_311_limit.csv', names=headers)
# Out:
# /Users/vincenthuang/.virtualenvs/comp598-hw4/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (8,17,20,31,32,34,35,36,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    40990076  11/20/2018 11:18:04 AM  11/21/2018 02:00:41 PM    DPR
# 1    40990078  11/20/2018 11:44:00 AM  11/20/2018 12:00:00 PM   DSNY
# 2    40990079  11/20/2018 07:00:00 PM  12/17/2018 01:07:00 PM   DSNY
# 3    40990080  11/20/2018 04:34:00 PM  11/27/2018 12:49:00 PM   DSNY
# 4    40990081  11/20/2018 04:10:00 PM  01/03/2019 12:42:00 PM   DSNY
#
#                           Agency Name                 Complaint Type  \
# 0  Department of Parks and Recreation                   Damaged Tree
# 1                      Queens East 12              Derelict Vehicles
# 2            Department of Sanitation  Electronics Waste Appointment
# 3            Department of Sanitation  Electronics Waste Appointment
# 4            Department of Sanitation  Electronics Waste Appointment
#
#                     Descriptor Location Type Incident Zip  \
# 0  Entire Tree Has Fallen Down        Street      11101.0
# ...

# %%
filtered_df = df[df['Created Date'].str.contains('2020')]

# %%
filtered_df.head()
# Out:
#         Unique Key            Created Date             Closed Date  \
# 13945     46920293  07/20/2020 10:51:12 AM  09/05/2020 12:32:48 PM
# 31489     46893148  07/17/2020 09:33:04 AM                     NaN
# 71568     46930483  07/21/2020 02:13:58 PM  09/05/2020 01:37:31 PM
# 168691    46997111  07/27/2020 12:56:33 PM  09/05/2020 08:51:14 AM
# 405247    45368846  01/12/2020 10:31:32 PM                     NaN
#
#                                          Agency  \
# 13945                                       DPR
# 31489                                       DPR
# 71568   MAYORâS OFFICE OF SPECIAL ENFORCEMENT
# 168691                                      DPR
# 405247                                      TLC
#
#                                     Agency Name  \
# 13945        Department of Parks and Recreation
# 31489        Department of Parks and Recreation
# 71568   Mayorâs Office of Special Enforcement
# 168691       Department of Parks and Recreation
# ...

# %%
filtered_df.to_csv('filtered_data.csv')

# %%
filtered_df['Zeip']
